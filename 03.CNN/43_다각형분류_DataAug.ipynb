# %% [markdown]
# # 원, 삼각형, 사각형 구분하기
# ## - 어려운 테스트 문제를 데이터 부풀리기를 이용한 경우

# %%
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.models import Sequential
#층을 담는 그릇(Sequential은 keras에 포함되어 있는데
# 딥러닝 모델을 한층 한층 쌓기 쉽게 해주는 함수)
from tensorflow.keras.layers import Dense
#층을 만드는 것(각 층이 가질 특성을 각각 다르게 지정 가능) 
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")

# seed값 생성
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## 데이터셋 부풀리기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 데이터셋 불러오기
train_datagen = ImageDataGenerator(
    rescale=1/255.0,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 2.0],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# %%
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
img = load_img('hard_handwriting_shape/train/triangle/triangle001.png')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

# %%
i = 0
for batch in train_datagen.flow(x, batch_size=1, save_to_dir='preview',
                                save_prefix='tri', save_format='png'):
    i += 1
    if i > 20:
        break

# %%
train_generator = train_datagen.flow_from_directory(
    'hard_handwriting_shape/train',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 45 images belonging to 3 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1/255.)
test_generator = test_datagen.flow_from_directory(
    'hard_handwriting_shape/test',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 15 images belonging to 3 classes.

# %% [markdown]
# 훈련시 데이터 부풀리기가 가능하지만 테스트 데이터는 부풀려서 할 수 없음

# %% [markdown]
# ## 모델 정의/설정/학습

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model = Sequential([ 
    Conv2D(32, (3,3), input_shape=(24,24,3), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 22, 22, 32)        896
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               819328
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 839,107
# Trainable params: 839,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## 모델 학습
# 케라스에서는 모델을 학습시킬 때 주로 fit() 함수를 사용하지만 제네레이터로 생성된 배치로 학습시킬 경우에는 fit_generator() 함수를 사용합니다. 본 예제에서는 ImageDataGenerator라는 제네레이터로 이미지를 담고 있는 배치로 학습시키기 때문에 fit_generator() 함수를 사용하겠습니다.
#
# ### 첫번째 인자 : 훈련데이터셋을 제공할 제네레이터를 지정합니다. 본 예제에서는 앞서 생성한 train_generator으로 지정합니다.
# ### steps_per_epoch : 한 epoch에 사용한 스텝 수를 지정합니다. 총 45개의 훈련 샘플이 있고 배치사이즈가 3이므로 15 스텝으로 지정. 데이터 부풀리기를 이용하여 100개씩 사용
# ### epochs : 전체 훈련 데이터셋에 대해 학습 반복 횟수를 지정합니다. 100번을 반복적으로 학습시켜 보겠습니다.
# ### validation_data : 검증데이터셋을 제공할 제네레이터를 지정합니다. 본 예제에서는 앞서 생성한 validation_generator으로 지정합니다.
# ### validation_steps : 한 epoch 종료 시 마다 검증할 때 사용되는 검증 스텝 수를 지정합니다. 홍 15개의 검증 샘플이 있고 배치사이즈가 3이므로 5 스텝으로 지정합니다.

# %%
model.fit(
        train_generator,
        steps_per_epoch=15,
        epochs=200,
        validation_data=test_generator,
        validation_steps=5,
        verbose=2
)
# Out:
# Epoch 1/200
# 15/15 - 0s - loss: 1.2012 - accuracy: 0.3333 - val_loss: 1.0848 - val_accuracy: 0.4667
# Epoch 2/200
# 15/15 - 0s - loss: 1.0502 - accuracy: 0.4444 - val_loss: 1.0516 - val_accuracy: 0.4667
# Epoch 3/200
# 15/15 - 0s - loss: 0.8591 - accuracy: 0.6222 - val_loss: 1.1808 - val_accuracy: 0.3333
# Epoch 4/200
# 15/15 - 0s - loss: 0.8767 - accuracy: 0.5333 - val_loss: 0.9027 - val_accuracy: 0.6000
# Epoch 5/200
# 15/15 - 0s - loss: 0.5727 - accuracy: 0.8222 - val_loss: 1.4032 - val_accuracy: 0.5333
# Epoch 6/200
# 15/15 - 0s - loss: 0.3846 - accuracy: 0.8667 - val_loss: 1.9456 - val_accuracy: 0.5333
# Epoch 7/200
# 15/15 - 0s - loss: 0.2487 - accuracy: 0.9111 - val_loss: 1.9282 - val_accuracy: 0.6000
# Epoch 8/200
# 15/15 - 0s - loss: 0.2760 - accuracy: 0.8889 - val_loss: 1.6899 - val_accuracy: 0.5333
# Epoch 9/200
# 15/15 - 0s - loss: 0.3270 - accuracy: 0.8889 - val_loss: 2.3651 - val_accuracy: 0.6000
# Epoch 10/200
# 15/15 - 0s - loss: 0.1357 - accuracy: 0.9333 - val_loss: 2.2034 - val_accuracy: 0.6000
# Epoch 11/200
# 15/15 - 0s - loss: 0.1678 - accuracy: 0.9556 - val_loss: 2.4589 - val_accuracy: 0.6667
# Epoch 12/200
# 15/15 - 0s - loss: 0.2687 - accuracy: 0.9333 - val_loss: 2.1802 - val_accuracy: 0.6667
# Epoch 13/200
# 15/15 - 0s - loss: 0.0633 - accuracy: 1.0000 - val_loss: 1.7041 - val_accuracy: 0.7333
# Epoch 14/200
# 15/15 - 0s - loss: 0.3456 - accuracy: 0.8667 - val_loss: 1.1388 - val_accuracy: 0.7333
# Epoch 15/200
# 15/15 - 0s - loss: 0.1502 - accuracy: 0.9778 - val_loss: 1.5195 - val_accuracy: 0.6000
# Epoch 16/200
# 15/15 - 0s - loss: 0.0744 - accuracy: 0.9333 - val_loss: 1.6487 - val_accuracy: 0.6000
# Epoch 17/200
# 15/15 - 0s - loss: 0.0857 - accuracy: 0.9778 - val_loss: 2.2704 - val_accuracy: 0.6000
# Epoch 18/200
# 15/15 - 0s - loss: 0.3754 - accuracy: 0.8889 - val_loss: 1.7704 - val_accuracy: 0.6667
# Epoch 19/200
# 15/15 - 0s - loss: 0.0317 - accuracy: 1.0000 - val_loss: 2.5344 - val_accuracy: 0.6000
# Epoch 20/200
# 15/15 - 0s - loss: 0.0379 - accuracy: 1.0000 - val_loss: 2.1562 - val_accuracy: 0.6000
# Epoch 21/200
# 15/15 - 0s - loss: 0.1522 - accuracy: 0.9333 - val_loss: 2.7117 - val_accuracy: 0.6000
# Epoch 22/200
# 15/15 - 0s - loss: 0.1011 - accuracy: 0.9556 - val_loss: 1.9815 - val_accuracy: 0.6000
# Epoch 23/200
# 15/15 - 0s - loss: 0.0394 - accuracy: 1.0000 - val_loss: 2.1303 - val_accuracy: 0.6000
# Epoch 24/200
# 15/15 - 0s - loss: 0.0392 - accuracy: 1.0000 - val_loss: 2.7308 - val_accuracy: 0.6000
# Epoch 25/200
# 15/15 - 0s - loss: 0.2785 - accuracy: 0.8889 - val_loss: 1.2614 - val_accuracy: 0.6667
# Epoch 26/200
# 15/15 - 0s - loss: 0.0462 - accuracy: 1.0000 - val_loss: 3.4813 - val_accuracy: 0.4667
# Epoch 27/200
# 15/15 - 0s - loss: 0.0363 - accuracy: 1.0000 - val_loss: 2.5977 - val_accuracy: 0.6000
# Epoch 28/200
# 15/15 - 0s - loss: 0.0987 - accuracy: 0.9556 - val_loss: 1.9274 - val_accuracy: 0.6667
# Epoch 29/200
# 15/15 - 0s - loss: 0.2971 - accuracy: 0.9333 - val_loss: 2.0623 - val_accuracy: 0.6667
# Epoch 30/200
# 15/15 - 0s - loss: 0.1404 - accuracy: 0.9556 - val_loss: 1.4188 - val_accuracy: 0.7333
# Epoch 31/200
# 15/15 - 0s - loss: 0.2326 - accuracy: 0.9333 - val_loss: 1.8878 - val_accuracy: 0.6000
# Epoch 32/200
# 15/15 - 0s - loss: 0.1016 - accuracy: 0.9556 - val_loss: 1.6644 - val_accuracy: 0.6667
# Epoch 33/200
# 15/15 - 0s - loss: 0.1478 - accuracy: 0.9333 - val_loss: 1.9109 - val_accuracy: 0.6667
# Epoch 34/200
# 15/15 - 0s - loss: 0.2573 - accuracy: 0.9111 - val_loss: 2.7128 - val_accuracy: 0.6667
# Epoch 35/200
# 15/15 - 0s - loss: 0.1274 - accuracy: 0.9778 - val_loss: 1.6389 - val_accuracy: 0.6667
# Epoch 36/200
# 15/15 - 0s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 1.5252 - val_accuracy: 0.7333
# Epoch 37/200
# 15/15 - 0s - loss: 0.0542 - accuracy: 0.9556 - val_loss: 1.7058 - val_accuracy: 0.8000
# Epoch 38/200
# 15/15 - 0s - loss: 0.0174 - accuracy: 1.0000 - val_loss: 3.0606 - val_accuracy: 0.6000
# Epoch 39/200
# 15/15 - 0s - loss: 0.0232 - accuracy: 1.0000 - val_loss: 2.5561 - val_accuracy: 0.7333
# Epoch 40/200
# 15/15 - 0s - loss: 0.0288 - accuracy: 1.0000 - val_loss: 2.2135 - val_accuracy: 0.7333
# Epoch 41/200
# 15/15 - 0s - loss: 0.0905 - accuracy: 0.9556 - val_loss: 2.8438 - val_accuracy: 0.7333
# Epoch 42/200
# 15/15 - 0s - loss: 0.0399 - accuracy: 0.9778 - val_loss: 1.9544 - val_accuracy: 0.6667
# Epoch 43/200
# 15/15 - 0s - loss: 0.0526 - accuracy: 0.9556 - val_loss: 1.7561 - val_accuracy: 0.7333
# Epoch 44/200
# 15/15 - 0s - loss: 0.0440 - accuracy: 0.9778 - val_loss: 2.5102 - val_accuracy: 0.7333
# Epoch 45/200
# 15/15 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 2.4522 - val_accuracy: 0.7333
# Epoch 46/200
# 15/15 - 0s - loss: 0.1342 - accuracy: 0.9111 - val_loss: 2.4954 - val_accuracy: 0.6667
# Epoch 47/200
# 15/15 - 0s - loss: 0.5436 - accuracy: 0.9111 - val_loss: 2.0308 - val_accuracy: 0.8000
# Epoch 48/200
# 15/15 - 0s - loss: 0.2895 - accuracy: 0.9333 - val_loss: 1.5579 - val_accuracy: 0.8000
# Epoch 49/200
# 15/15 - 0s - loss: 0.0653 - accuracy: 0.9778 - val_loss: 1.9105 - val_accuracy: 0.7333
# Epoch 50/200
# 15/15 - 0s - loss: 0.0842 - accuracy: 0.9778 - val_loss: 1.9191 - val_accuracy: 0.7333
# Epoch 51/200
# 15/15 - 0s - loss: 0.0371 - accuracy: 1.0000 - val_loss: 2.0931 - val_accuracy: 0.7333
# Epoch 52/200
# 15/15 - 0s - loss: 0.0697 - accuracy: 0.9778 - val_loss: 1.8414 - val_accuracy: 0.8000
# Epoch 53/200
# 15/15 - 0s - loss: 0.0412 - accuracy: 0.9778 - val_loss: 1.8837 - val_accuracy: 0.8000
# Epoch 54/200
# 15/15 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 2.0507 - val_accuracy: 0.7333
# Epoch 55/200
# 15/15 - 0s - loss: 0.0471 - accuracy: 0.9778 - val_loss: 2.4879 - val_accuracy: 0.6667
# Epoch 56/200
# 15/15 - 0s - loss: 0.2202 - accuracy: 0.9111 - val_loss: 2.2123 - val_accuracy: 0.7333
# Epoch 57/200
# 15/15 - 0s - loss: 0.0797 - accuracy: 0.9778 - val_loss: 1.8422 - val_accuracy: 0.8000
# Epoch 58/200
# 15/15 - 0s - loss: 0.0516 - accuracy: 0.9778 - val_loss: 2.6499 - val_accuracy: 0.6667
# Epoch 59/200
# 15/15 - 0s - loss: 0.1209 - accuracy: 0.9556 - val_loss: 2.9820 - val_accuracy: 0.6000
# Epoch 60/200
# 15/15 - 0s - loss: 0.0257 - accuracy: 1.0000 - val_loss: 2.0110 - val_accuracy: 0.7333
# Epoch 61/200
# 15/15 - 0s - loss: 0.0533 - accuracy: 0.9778 - val_loss: 2.1853 - val_accuracy: 0.7333
# Epoch 62/200
# 15/15 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 3.4044 - val_accuracy: 0.6000
# Epoch 63/200
# 15/15 - 0s - loss: 0.1363 - accuracy: 0.9333 - val_loss: 2.7690 - val_accuracy: 0.6000
# Epoch 64/200
# 15/15 - 0s - loss: 0.2961 - accuracy: 0.8889 - val_loss: 1.3911 - val_accuracy: 0.8000
# Epoch 65/200
# 15/15 - 0s - loss: 0.0428 - accuracy: 0.9778 - val_loss: 3.3784 - val_accuracy: 0.5333
# Epoch 66/200
# 15/15 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 2.0487 - val_accuracy: 0.8000
# Epoch 67/200
# 15/15 - 0s - loss: 0.0748 - accuracy: 0.9778 - val_loss: 2.2507 - val_accuracy: 0.7333
# Epoch 68/200
# 15/15 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 2.5672 - val_accuracy: 0.6667
# Epoch 69/200
# 15/15 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 3.0988 - val_accuracy: 0.6667
# Epoch 70/200
# 15/15 - 0s - loss: 0.1408 - accuracy: 0.9333 - val_loss: 1.7222 - val_accuracy: 0.8000
# Epoch 71/200
# 15/15 - 0s - loss: 0.1302 - accuracy: 0.9333 - val_loss: 1.5735 - val_accuracy: 0.8000
# Epoch 72/200
# 15/15 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 1.4902 - val_accuracy: 0.8000
# Epoch 73/200
# 15/15 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 1.6693 - val_accuracy: 0.8000
# Epoch 74/200
# 15/15 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.9245 - val_accuracy: 0.8000
# Epoch 75/200
# 15/15 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 2.4388 - val_accuracy: 0.8000
# Epoch 76/200
# 15/15 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 3.1698 - val_accuracy: 0.6000
# Epoch 77/200
# 15/15 - 0s - loss: 0.0465 - accuracy: 0.9778 - val_loss: 3.0899 - val_accuracy: 0.6667
# Epoch 78/200
# 15/15 - 0s - loss: 0.1109 - accuracy: 0.9778 - val_loss: 3.7458 - val_accuracy: 0.6667
# Epoch 79/200
# 15/15 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 3.3271 - val_accuracy: 0.8000
# Epoch 80/200
# 15/15 - 0s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 2.8357 - val_accuracy: 0.8000
# Epoch 81/200
# 15/15 - 0s - loss: 0.0516 - accuracy: 0.9778 - val_loss: 2.6566 - val_accuracy: 0.8000
# Epoch 82/200
# 15/15 - 0s - loss: 0.0790 - accuracy: 0.9556 - val_loss: 2.8803 - val_accuracy: 0.6667
# Epoch 83/200
# 15/15 - 0s - loss: 0.0352 - accuracy: 0.9778 - val_loss: 2.6896 - val_accuracy: 0.8000
# Epoch 84/200
# 15/15 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 2.3432 - val_accuracy: 0.8000
# Epoch 85/200
# 15/15 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.3495 - val_accuracy: 0.8000
# Epoch 86/200
# 15/15 - 0s - loss: 0.0270 - accuracy: 0.9778 - val_loss: 2.5502 - val_accuracy: 0.8000
# Epoch 87/200
# 15/15 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 3.7361 - val_accuracy: 0.6667
# Epoch 88/200
# 15/15 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.0411 - val_accuracy: 0.6667
# Epoch 89/200
# 15/15 - 0s - loss: 0.1068 - accuracy: 0.9778 - val_loss: 2.3566 - val_accuracy: 0.8000
# Epoch 90/200
# 15/15 - 0s - loss: 0.0811 - accuracy: 0.9778 - val_loss: 2.3017 - val_accuracy: 0.7333
# Epoch 91/200
# 15/15 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 2.4969 - val_accuracy: 0.7333
# Epoch 92/200
# 15/15 - 0s - loss: 0.0270 - accuracy: 0.9778 - val_loss: 2.0646 - val_accuracy: 0.7333
# Epoch 93/200
# 15/15 - 0s - loss: 0.1137 - accuracy: 0.9778 - val_loss: 2.0443 - val_accuracy: 0.8000
# Epoch 94/200
# 15/15 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 2.8019 - val_accuracy: 0.6667
# Epoch 95/200
# 15/15 - 0s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 2.4280 - val_accuracy: 0.6667
# Epoch 96/200
# 15/15 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 2.3256 - val_accuracy: 0.6667
# Epoch 97/200
# 15/15 - 0s - loss: 0.0536 - accuracy: 0.9556 - val_loss: 2.6110 - val_accuracy: 0.6667
# Epoch 98/200
# 15/15 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.4266 - val_accuracy: 0.6667
# Epoch 99/200
# 15/15 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 2.7540 - val_accuracy: 0.6667
# Epoch 100/200
# 15/15 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 2.9817 - val_accuracy: 0.6667
# Epoch 101/200
# 15/15 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 3.5335 - val_accuracy: 0.6000
# Epoch 102/200
# 15/15 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 5.1919 - val_accuracy: 0.5333
# Epoch 103/200
# 15/15 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 4.3573 - val_accuracy: 0.6000
# Epoch 104/200
# 15/15 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.5754 - val_accuracy: 0.6667
# Epoch 105/200
# 15/15 - 0s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 4.0215 - val_accuracy: 0.6000
# Epoch 106/200
# 15/15 - 0s - loss: 0.2491 - accuracy: 0.8889 - val_loss: 1.8714 - val_accuracy: 0.8000
# Epoch 107/200
# 15/15 - 0s - loss: 0.0563 - accuracy: 0.9556 - val_loss: 2.8143 - val_accuracy: 0.6667
# Epoch 108/200
# 15/15 - 0s - loss: 0.0353 - accuracy: 0.9778 - val_loss: 2.2414 - val_accuracy: 0.6667
# Epoch 109/200
# 15/15 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 2.2358 - val_accuracy: 0.7333
# Epoch 110/200
# 15/15 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 2.4366 - val_accuracy: 0.6667
# Epoch 111/200
# 15/15 - 0s - loss: 0.0386 - accuracy: 0.9778 - val_loss: 2.1312 - val_accuracy: 0.8000
# Epoch 112/200
# 15/15 - 0s - loss: 0.0813 - accuracy: 0.9778 - val_loss: 2.1272 - val_accuracy: 0.7333
# Epoch 113/200
# 15/15 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 2.6503 - val_accuracy: 0.6000
# Epoch 114/200
# 15/15 - 0s - loss: 0.0508 - accuracy: 0.9778 - val_loss: 2.5208 - val_accuracy: 0.6667
# Epoch 115/200
# 15/15 - 0s - loss: 0.0779 - accuracy: 0.9778 - val_loss: 1.7562 - val_accuracy: 0.8667
# Epoch 116/200
# 15/15 - 0s - loss: 0.0393 - accuracy: 0.9778 - val_loss: 1.8902 - val_accuracy: 0.8667
# Epoch 117/200
# 15/15 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.3583 - val_accuracy: 0.8000
# Epoch 118/200
# 15/15 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.2155 - val_accuracy: 0.8000
# Epoch 119/200
# 15/15 - 0s - loss: 0.0676 - accuracy: 0.9778 - val_loss: 3.2459 - val_accuracy: 0.7333
# Epoch 120/200
# 15/15 - 0s - loss: 0.2596 - accuracy: 0.8889 - val_loss: 1.4925 - val_accuracy: 0.8667
# Epoch 121/200
# 15/15 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 6.0645 - val_accuracy: 0.4667
# Epoch 122/200
# 15/15 - 0s - loss: 0.0246 - accuracy: 0.9778 - val_loss: 2.6080 - val_accuracy: 0.6667
# Epoch 123/200
# 15/15 - 0s - loss: 0.0611 - accuracy: 0.9556 - val_loss: 1.6225 - val_accuracy: 0.8667
# Epoch 124/200
# 15/15 - 0s - loss: 0.0633 - accuracy: 0.9778 - val_loss: 2.2254 - val_accuracy: 0.7333
# Epoch 125/200
# 15/15 - 0s - loss: 0.3877 - accuracy: 0.9333 - val_loss: 2.8981 - val_accuracy: 0.6667
# Epoch 126/200
# 15/15 - 0s - loss: 0.0509 - accuracy: 0.9778 - val_loss: 2.9828 - val_accuracy: 0.6000
# Epoch 127/200
# 15/15 - 0s - loss: 0.0574 - accuracy: 0.9778 - val_loss: 2.9801 - val_accuracy: 0.6667
# Epoch 128/200
# 15/15 - 0s - loss: 0.0603 - accuracy: 0.9778 - val_loss: 2.4690 - val_accuracy: 0.7333
# Epoch 129/200
# 15/15 - 0s - loss: 0.0230 - accuracy: 0.9778 - val_loss: 1.9062 - val_accuracy: 0.8000
# Epoch 130/200
# 15/15 - 0s - loss: 0.0776 - accuracy: 0.9778 - val_loss: 2.0382 - val_accuracy: 0.7333
# Epoch 131/200
# 15/15 - 0s - loss: 0.0493 - accuracy: 0.9778 - val_loss: 1.9965 - val_accuracy: 0.7333
# Epoch 132/200
# 15/15 - 0s - loss: 0.0960 - accuracy: 0.9778 - val_loss: 2.2562 - val_accuracy: 0.8000
# Epoch 133/200
# 15/15 - 0s - loss: 0.0679 - accuracy: 0.9556 - val_loss: 2.8761 - val_accuracy: 0.6667
# Epoch 134/200
# 15/15 - 0s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 2.1489 - val_accuracy: 0.6667
# Epoch 135/200
# 15/15 - 0s - loss: 0.1459 - accuracy: 0.9556 - val_loss: 1.9722 - val_accuracy: 0.7333
# Epoch 136/200
# 15/15 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 1.9405 - val_accuracy: 0.8000
# Epoch 137/200
# 15/15 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 2.0424 - val_accuracy: 0.8000
# Epoch 138/200
# 15/15 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 2.2298 - val_accuracy: 0.7333
# Epoch 139/200
# 15/15 - 0s - loss: 9.8516e-04 - accuracy: 1.0000 - val_loss: 2.3775 - val_accuracy: 0.7333
# Epoch 140/200
# 15/15 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 2.5359 - val_accuracy: 0.6667
# Epoch 141/200
# 15/15 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.5966 - val_accuracy: 0.6667
# Epoch 142/200
# 15/15 - 0s - loss: 0.0790 - accuracy: 0.9778 - val_loss: 2.7346 - val_accuracy: 0.7333
# Epoch 143/200
# 15/15 - 0s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 4.7018 - val_accuracy: 0.4667
# Epoch 144/200
# 15/15 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 4.7769 - val_accuracy: 0.4667
# Epoch 145/200
# 15/15 - 0s - loss: 0.0340 - accuracy: 0.9778 - val_loss: 3.9381 - val_accuracy: 0.5333
# Epoch 146/200
# 15/15 - 0s - loss: 0.0274 - accuracy: 0.9778 - val_loss: 2.6397 - val_accuracy: 0.6667
# Epoch 147/200
# 15/15 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.0567 - val_accuracy: 0.8667
# Epoch 148/200
# 15/15 - 0s - loss: 0.0303 - accuracy: 1.0000 - val_loss: 1.9595 - val_accuracy: 0.8000
# Epoch 149/200
# 15/15 - 0s - loss: 0.0366 - accuracy: 0.9778 - val_loss: 2.0088 - val_accuracy: 0.8667
# Epoch 150/200
# 15/15 - 0s - loss: 0.0652 - accuracy: 0.9778 - val_loss: 2.2751 - val_accuracy: 0.7333
# Epoch 151/200
# 15/15 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4963 - val_accuracy: 0.8000
# Epoch 152/200
# 15/15 - 0s - loss: 0.1337 - accuracy: 0.9111 - val_loss: 1.4405 - val_accuracy: 0.8000
# Epoch 153/200
# 15/15 - 0s - loss: 0.1424 - accuracy: 0.9556 - val_loss: 1.6443 - val_accuracy: 0.8000
# Epoch 154/200
# 15/15 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 3.6966 - val_accuracy: 0.5333
# Epoch 155/200
# 15/15 - 0s - loss: 0.0394 - accuracy: 0.9778 - val_loss: 2.6817 - val_accuracy: 0.7333
# Epoch 156/200
# 15/15 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.5370 - val_accuracy: 0.8000
# Epoch 157/200
# 15/15 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 2.5166 - val_accuracy: 0.8000
# Epoch 158/200
# 15/15 - 0s - loss: 0.0334 - accuracy: 0.9778 - val_loss: 5.5448 - val_accuracy: 0.5333
# Epoch 159/200
# 15/15 - 0s - loss: 0.1090 - accuracy: 0.9556 - val_loss: 2.8757 - val_accuracy: 0.7333
# Epoch 160/200
# 15/15 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 2.6424 - val_accuracy: 0.8000
# Epoch 161/200
# 15/15 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.6551 - val_accuracy: 0.8000
# Epoch 162/200
# 15/15 - 0s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 2.5405 - val_accuracy: 0.8000
# Epoch 163/200
# 15/15 - 0s - loss: 5.8899e-04 - accuracy: 1.0000 - val_loss: 2.5565 - val_accuracy: 0.8000
# Epoch 164/200
# 15/15 - 0s - loss: 6.8265e-04 - accuracy: 1.0000 - val_loss: 2.5819 - val_accuracy: 0.8000
# Epoch 165/200
# 15/15 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.6164 - val_accuracy: 0.8000
# Epoch 166/200
# 15/15 - 0s - loss: 2.1068e-04 - accuracy: 1.0000 - val_loss: 2.6417 - val_accuracy: 0.8000
# Epoch 167/200
# 15/15 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 2.7814 - val_accuracy: 0.8000
# Epoch 168/200
# 15/15 - 0s - loss: 7.5757e-04 - accuracy: 1.0000 - val_loss: 2.8240 - val_accuracy: 0.8000
# Epoch 169/200
# 15/15 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.8046 - val_accuracy: 0.8000
# Epoch 170/200
# 15/15 - 0s - loss: 5.7214e-04 - accuracy: 1.0000 - val_loss: 2.8136 - val_accuracy: 0.8000
# Epoch 171/200
# 15/15 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.8957 - val_accuracy: 0.8000
# Epoch 172/200
# 15/15 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 3.0145 - val_accuracy: 0.8000
# Epoch 173/200
# 15/15 - 0s - loss: 1.0941e-04 - accuracy: 1.0000 - val_loss: 4.9009 - val_accuracy: 0.5333
# Epoch 174/200
# 15/15 - 0s - loss: 1.4358e-04 - accuracy: 1.0000 - val_loss: 5.4986 - val_accuracy: 0.5333
# Epoch 175/200
# 15/15 - 0s - loss: 6.9293e-04 - accuracy: 1.0000 - val_loss: 5.5945 - val_accuracy: 0.5333
# Epoch 176/200
# 15/15 - 0s - loss: 6.9252e-04 - accuracy: 1.0000 - val_loss: 5.5210 - val_accuracy: 0.5333
# Epoch 177/200
# 15/15 - 0s - loss: 4.6377e-04 - accuracy: 1.0000 - val_loss: 5.4614 - val_accuracy: 0.5333
# Epoch 178/200
# 15/15 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 5.1186 - val_accuracy: 0.5333
# Epoch 179/200
# 15/15 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.9589 - val_accuracy: 0.5333
# Epoch 180/200
# 15/15 - 0s - loss: 0.0325 - accuracy: 0.9778 - val_loss: 4.9490 - val_accuracy: 0.5333
# Epoch 181/200
# 15/15 - 0s - loss: 0.1522 - accuracy: 0.9556 - val_loss: 5.3323 - val_accuracy: 0.5333
# Epoch 182/200
# 15/15 - 0s - loss: 0.0310 - accuracy: 0.9778 - val_loss: 4.6397 - val_accuracy: 0.6000
# Epoch 183/200
# 15/15 - 0s - loss: 0.1119 - accuracy: 0.9556 - val_loss: 3.7905 - val_accuracy: 0.5333
# Epoch 184/200
# 15/15 - 0s - loss: 0.1045 - accuracy: 0.9778 - val_loss: 2.6505 - val_accuracy: 0.6667
# Epoch 185/200
# 15/15 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.5671 - val_accuracy: 0.6667
# Epoch 186/200
# 15/15 - 0s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 2.2066 - val_accuracy: 0.8000
# Epoch 187/200
# 15/15 - 0s - loss: 0.0373 - accuracy: 0.9778 - val_loss: 2.2179 - val_accuracy: 0.8000
# Epoch 188/200
# 15/15 - 0s - loss: 0.0257 - accuracy: 0.9778 - val_loss: 3.0238 - val_accuracy: 0.6667
# Epoch 189/200
# 15/15 - 0s - loss: 0.0934 - accuracy: 0.9778 - val_loss: 3.2625 - val_accuracy: 0.6667
# Epoch 190/200
# 15/15 - 0s - loss: 2.1522e-04 - accuracy: 1.0000 - val_loss: 3.3884 - val_accuracy: 0.6667
# Epoch 191/200
# 15/15 - 0s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 2.1965 - val_accuracy: 0.7333
# Epoch 192/200
# 15/15 - 0s - loss: 4.5616e-04 - accuracy: 1.0000 - val_loss: 2.0582 - val_accuracy: 0.7333
# Epoch 193/200
# 15/15 - 0s - loss: 0.0292 - accuracy: 1.0000 - val_loss: 2.0826 - val_accuracy: 0.8000
# Epoch 194/200
# 15/15 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.2054 - val_accuracy: 0.8000
# Epoch 195/200
# 15/15 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 2.3681 - val_accuracy: 0.8000
# Epoch 196/200
# 15/15 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 2.4002 - val_accuracy: 0.8000
# Epoch 197/200
# 15/15 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.4155 - val_accuracy: 0.8000
# Epoch 198/200
# 15/15 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.4545 - val_accuracy: 0.8000
# Epoch 199/200
# 15/15 - 0s - loss: 0.0539 - accuracy: 0.9778 - val_loss: 2.8220 - val_accuracy: 0.6667
# Epoch 200/200
# 15/15 - 0s - loss: 2.2934e-04 - accuracy: 1.0000 - val_loss: 2.9907 - val_accuracy: 0.7333

# %%
model.evaluate(test_generator, steps=5)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 2.9907 - accuracy: 0.7333
# [2.9906866550445557, 0.7333333492279053]
